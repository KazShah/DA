# %%
#impoting Libraries
from sqlalchemy import create_engine
import pandas as pd
import os
import warnings
from zipfile import ZipFile
warnings.filterwarnings('ignore')

# %%
#Loading Metro files from Jemena.zip
all_files = ZipFile("Jemena.zip",'r')
files = all_files.namelist()
#files
data=[]
files_metro = [f for f in files if f[16:21] == 'Metro']
file_count=0
for f in files_metro:
    df_Jemena_temp=pd.read_excel(all_files.open(f))
    data.append(df_Jemena_temp)
    print(f)
    file_count=file_count+1
df_Jem=pd.concat(data)
print("Total Files Loaded: ",file_count)
# Out:
# Jemena/DeID MelbMetro_ControlLoad&PV_500_201904-201906.xlsx
# Jemena/DeID MelbMetro_ControlLoad&PV_500_201907-201909.xlsx
# Jemena/DeID MelbMetro_ControlLoad&PV_500_201910-201912.xlsx
# Jemena/DeID MelbMetro_ControlLoad&PV_500_202001-202003.xlsx
# Jemena/DeID MelbMetro_ControlLoad_1000_201904-201906.xlsx
# Jemena/DeID MelbMetro_ControlLoad_1000_201907-201909.xlsx
# Jemena/DeID MelbMetro_ControlLoad_1000_201910-201912.xlsx
# Jemena/DeID MelbMetro_ControlLoad_1000_202001-202003.xlsx
# Total Files Loaded:  8

# %%
df_Jem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1057197 entries, 0 to 176886
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   C4NET_NMI_ID                 1057189 non-null  float64
#  1   C4NET_METER_ID               1057189 non-null  float64
#  2   REGISTER_ID                  1057189 non-null  object
#  3   METER_REG_ACTIVE_READING_DT  1057189 non-null  datetime64[ns]
#  4   POSTAL_CD                    1057189 non-null  float64
#  5   CITY                         1057189 non-null  object
#  6   ESTIMATE_READ_BITMASK_IND    1057189 non-null  float64
#  7   MTR_REG_ACT_ENERGY_01_KWH    1057189 non-null  float64
#  8   MTR_REG_ACT_ENERGY_02_KWH    1057189 non-null  float64
#  9   MTR_REG_ACT_ENERGY_03_KWH    1057189 non-null  float64
#  10  MTR_REG_ACT_ENERGY_04_KWH    1057189 non-null  float64
#  11  MTR_REG_ACT_ENERGY_05_KWH    1057189 non-null  float64
# ...

# %%
# delete row with null values
df_Jem = df_Jem.dropna(how='any',axis=0)

# %%
# Delete total column
#df_Jem = df_Jem.drop(['TOTAL'], axis=1)

# %%
# Format interval values from columns to rows
#need to check
#df_Jem_new = df_Jem.melt(id_vars=["C4NET_NMI_ID", "C4NET_METER_ID","REGISTER_ID","METER_REG_ACTIVE_READING_DT","POSTAL_CD","CITY","ESTIMATE_READ_BITMASK_IND",'TOTAL'], 
 #       var_name="Interval", 
  #      value_name="kWh")
#df_Jem_new.head()
# Out:
#    C4NET_NMI_ID  C4NET_METER_ID REGISTER_ID METER_REG_ACTIVE_READING_DT  \
# 0  1.651153e+09        572287.0          B1                  2019-04-01
# 1  1.651153e+09        572287.0          E1                  2019-04-01
# 2  1.651153e+09        572287.0          B1                  2019-04-02
# 3  1.651153e+09        572287.0          E1                  2019-04-02
# 4  1.651153e+09        572287.0          B1                  2019-04-03
#
#    POSTAL_CD       CITY  ESTIMATE_READ_BITMASK_IND    TOTAL  \
# 0     3015.0  SPOTSWOOD                        0.0   4.8745
# 1     3015.0  SPOTSWOOD                        0.0  11.6677
# 2     3015.0  SPOTSWOOD                        0.0  20.1496
# 3     3015.0  SPOTSWOOD                        0.0  12.9555
# 4     3015.0  SPOTSWOOD                        0.0   9.0870
#
#                     Interval     kWh
# 0  MTR_REG_ACT_ENERGY_01_KWH     0.0
# 1  MTR_REG_ACT_ENERGY_01_KWH  0.0812
# 2  MTR_REG_ACT_ENERGY_01_KWH     0.0
# ...

# %%
df_Jem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1057189 entries, 0 to 176885
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   C4NET_NMI_ID                 1057189 non-null  float64
#  1   C4NET_METER_ID               1057189 non-null  float64
#  2   REGISTER_ID                  1057189 non-null  object
#  3   METER_REG_ACTIVE_READING_DT  1057189 non-null  datetime64[ns]
#  4   POSTAL_CD                    1057189 non-null  float64
#  5   CITY                         1057189 non-null  object
#  6   ESTIMATE_READ_BITMASK_IND    1057189 non-null  float64
#  7   MTR_REG_ACT_ENERGY_01_KWH    1057189 non-null  float64
#  8   MTR_REG_ACT_ENERGY_02_KWH    1057189 non-null  float64
#  9   MTR_REG_ACT_ENERGY_03_KWH    1057189 non-null  float64
#  10  MTR_REG_ACT_ENERGY_04_KWH    1057189 non-null  float64
#  11  MTR_REG_ACT_ENERGY_05_KWH    1057189 non-null  float64
# ...

# %%
#df_Jem_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50745072 entries, 0 to 50745071
# Data columns (total 10 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   C4NET_NMI_ID                 float64
#  1   C4NET_METER_ID               float64
#  2   REGISTER_ID                  object
#  3   METER_REG_ACTIVE_READING_DT  datetime64[ns]
#  4   POSTAL_CD                    float64
#  5   CITY                         object
#  6   ESTIMATE_READ_BITMASK_IND    float64
#  7   TOTAL                        float64
#  8   Interval                     object
#  9   kWh                          object
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 3.8+ GB

# %%
# Adding Column Metro
df_Jem['Area'] = 'Metro'
#df_Jem_region['Area'] = 'Regional'

# %%
df_Jem.rename(columns={'C4NET_NMI_ID':'nmi', 'C4NET_METER_ID':'c4net_id','REGISTER_ID':'channel','METER_REG_ACTIVE_READING_DT':'read_date','POSTAL_CD':'postcode','CITY':'City','TOTAL':'Total Usage (kWh)'}, inplace=True)
#df_Jem_region.rename(columns={'C4NET_NMI_ID':'nmi', 'C4NET_METER_ID':'c4net_id','REGISTER_ID':'channel','METER_REG_ACTIVE_READING_DT':'read_date','POSTAL_CD':'postcode','CITY':'City','TOTAL':'Total Usage (kWh)'}, inplace=True)

# %%
# Change column names
#df_Jem_new.rename(columns={'C4NET_NMI_ID':'nmi', 'C4NET_METER_ID':'c4net_id','REGISTER_ID':'channel','METER_REG_ACTIVE_READING_DT':'read_date','POSTAL_CD':'postcode','CITY':'City','TOTAL':'Total Usage (kWh)'}, inplace=True)

# %%
df_Jem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1057189 entries, 0 to 176885
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   nmi                        1057189 non-null  float64
#  1   c4net_id                   1057189 non-null  float64
#  2   channel                    1057189 non-null  object
#  3   read_date                  1057189 non-null  datetime64[ns]
#  4   postcode                   1057189 non-null  float64
#  5   City                       1057189 non-null  object
#  6   ESTIMATE_READ_BITMASK_IND  1057189 non-null  float64
#  7   MTR_REG_ACT_ENERGY_01_KWH  1057189 non-null  float64
#  8   MTR_REG_ACT_ENERGY_02_KWH  1057189 non-null  float64
#  9   MTR_REG_ACT_ENERGY_03_KWH  1057189 non-null  float64
#  10  MTR_REG_ACT_ENERGY_04_KWH  1057189 non-null  float64
#  11  MTR_REG_ACT_ENERGY_05_KWH  1057189 non-null  float64
# ...

# %%
#df_Jem_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1039398 entries, 0 to 173456
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   nmi                        1039398 non-null  float64
#  1   c4net_id                   1039398 non-null  float64
#  2   channel                    1039398 non-null  object
#  3   read_date                  1039398 non-null  datetime64[ns]
#  4   postcode                   1039398 non-null  float64
#  5   City                       1039398 non-null  object
#  6   ESTIMATE_READ_BITMASK_IND  1039398 non-null  float64
#  7   MTR_REG_ACT_ENERGY_01_KWH  1039398 non-null  float64
#  8   MTR_REG_ACT_ENERGY_02_KWH  1039398 non-null  float64
#  9   MTR_REG_ACT_ENERGY_03_KWH  1039398 non-null  float64
#  10  MTR_REG_ACT_ENERGY_04_KWH  1039398 non-null  float64
#  11  MTR_REG_ACT_ENERGY_05_KWH  1039398 non-null  float64
# ...

# %%
#df_Jem_new.nmi=df_Jem_new.nmi.astype(int)
#df_Jem_new.c4net_id=df_Jem_new.c4net_id.astype(int)
#df_Jem_new.postcode=df_Jem_new.postcode.astype(int)
#df_Jem_new.dtypes
# Out:
# nmi                                   int32
# c4net_id                              int32
# channel                              object
# read_date                    datetime64[ns]
# postcode                              int32
# City                                 object
# ESTIMATE_READ_BITMASK_IND           float64
# Total Usage (kWh)                   float64
# Interval                             object
# kWh                                  object
# Area                                 object
# dtype: object

# %%
#loading Regional files from Jemena.zip
all_files = ZipFile("Jemena.zip",'r')
files = all_files.namelist()
#files
data=[]
files_region = [f for f in files if f[16:24] == 'Regional']
file_count=0
for f in files_region:
    df_Jemena_temp_reg=pd.read_excel(all_files.open(f))
    data.append(df_Jemena_temp_reg)
    print(f)
    file_count=file_count+1
df_Jem_region=pd.concat(data)
print("Total Files Loaded: ",file_count)
# Out:
# Jemena/DeID MelbRegional_ControlLoad&PV_500_201904-201906.xlsx
# Jemena/DeID MelbRegional_ControlLoad&PV_500_201907-201909.xlsx
# Jemena/DeID MelbRegional_ControlLoad&PV_500_201910-201912.xlsx
# Jemena/DeID MelbRegional_ControlLoad&PV_500_202001-202003.xlsx
# Jemena/DeID MelbRegional_ControlLoad_1000_201904-201906.xlsx
# Jemena/DeID MelbRegional_ControlLoad_1000_201907-201909.xlsx
# Jemena/DeID MelbRegional_ControlLoad_1000_201910-201912.xlsx
# Jemena/DeID MelbRegional_ControlLoad_1000_202001-202003.xlsx
# Total Files Loaded:  8

# %%
# delete row with null values
df_Jem_region = df_Jem_region.dropna(how='any',axis=0)

# %%
# Format interval values from columns to rows
#df_Jem_region_new = df_Jem_region.melt(id_vars=["C4NET_NMI_ID", "C4NET_METER_ID","REGISTER_ID","METER_REG_ACTIVE_READING_DT","POSTAL_CD","CITY","ESTIMATE_READ_BITMASK_IND",'TOTAL'], 
 #       var_name="Interval", 
  #      value_name="kWh")
#df_Jem_region_new.head()
# Out:
#    C4NET_NMI_ID  C4NET_METER_ID REGISTER_ID METER_REG_ACTIVE_READING_DT  \
# 0  1.964803e+09        927571.0          E1                  2019-04-01
# 1  1.964803e+09        927571.0          E1                  2019-04-02
# 2  1.964803e+09        927571.0          E1                  2019-04-03
# 3  1.964803e+09        927571.0          E1                  2019-04-04
# 4  1.964803e+09        927571.0          E1                  2019-04-05
#
#    POSTAL_CD            CITY  ESTIMATE_READ_BITMASK_IND    TOTAL  \
# 0     3048.0  MEADOW HEIGHTS                        0.0  18.3486
# 1     3048.0  MEADOW HEIGHTS                        0.0  19.2613
# 2     3048.0  MEADOW HEIGHTS                        0.0  21.9866
# 3     3048.0  MEADOW HEIGHTS                        0.0  19.9861
# 4     3048.0  MEADOW HEIGHTS                        0.0  19.1551
#
#                     Interval     kWh
# 0  MTR_REG_ACT_ENERGY_01_KWH  0.2562
# 1  MTR_REG_ACT_ENERGY_01_KWH   0.375
# ...

# %%
# Adding Column Region
df_Jem_region['Area'] = 'Region'

# %%
# Change column names
df_Jem_region.rename(columns={'C4NET_NMI_ID':'nmi', 'C4NET_METER_ID':'c4net_id','REGISTER_ID':'channel','METER_REG_ACTIVE_READING_DT':'read_date','POSTAL_CD':'postcode','CITY':'City','TOTAL':'Total Usage (kWh)'}, inplace=True)

# %%
#df_Jem_region_new.nmi=df_Jem_region_new.nmi.astype(int)
#df_Jem_region_new.c4net_id=df_Jem_region_new.c4net_id.astype(int)
#df_Jem_region_new.postcode=df_Jem_region_new.postcode.astype(int)
#df_Jem_region_new.dtypes
# Out:
# nmi                                   int32
# c4net_id                              int32
# channel                              object
# read_date                    datetime64[ns]
# postcode                              int32
# City                                 object
# ESTIMATE_READ_BITMASK_IND           float64
# Total Usage (kWh)                   float64
# Interval                             object
# kWh                                  object
# Area                                 object
# dtype: object

# %%
#Merging both datasets
Jemena_complete=pd.concat([df_Jem,df_Jem_region],ignore_index=True, sort=False)

# %%
Jemena_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2096587 entries, 0 to 2096586
# Data columns (total 57 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   nmi                        float64
#  1   c4net_id                   float64
#  2   channel                    object
#  3   read_date                  datetime64[ns]
#  4   postcode                   int32
#  5   City                       object
#  6   ESTIMATE_READ_BITMASK_IND  float64
#  7   MTR_REG_ACT_ENERGY_01_KWH  float64
#  8   MTR_REG_ACT_ENERGY_02_KWH  float64
#  9   MTR_REG_ACT_ENERGY_03_KWH  float64
#  10  MTR_REG_ACT_ENERGY_04_KWH  float64
#  11  MTR_REG_ACT_ENERGY_05_KWH  float64
#  12  MTR_REG_ACT_ENERGY_06_KWH  float64
#  13  MTR_REG_ACT_ENERGY_07_KWH  float64
#  14  MTR_REG_ACT_ENERGY_08_KWH  float64
#  15  MTR_REG_ACT_ENERGY_09_KWH  float64
#  16  MTR_REG_ACT_ENERGY_10_KWH  float64
#  17  MTR_REG_ACT_ENERGY_11_KWH  float64
#  18  MTR_REG_ACT_ENERGY_12_KWH  float64
# ...

# %%
Jemena_complete['MTR_REG_ACT_ENERGY_48_KWH'].head()
# Out:
# 0         0
# 1    0.1375
# 2         0
# 3    0.1125
# 4         0
# Name: MTR_REG_ACT_ENERGY_48_KWH, dtype: object

# %%
Jemena_complete.MTR_REG_ACT_ENERGY_48_KWH=Jemena_complete.MTR_REG_ACT_ENERGY_48_KWH.astype(float)
Jemena_complete.postcode=Jemena_complete.postcode.astype(int)

# %%
#Connecting to mysqlserver
myDB=create_engine('mysql+mysqlconnector://root:Shah3214@localhost/solar_energy',pool_pre_ping=True)

# %%
#Transfereing data to sql db
with myDB.connect() as conn,conn.begin():
    Jemena_complete.to_sql('jemena_complete_area_div',conn, if_exists='append',chunksize=10000,index=False)

# %%
df_Jem_region.head()
# Out:
#             nmi  c4net_id channel  read_date  postcode            City  \
# 0  1.964803e+09  927571.0      E1 2019-04-01    3048.0  MEADOW HEIGHTS
# 1  1.964803e+09  927571.0      E1 2019-04-02    3048.0  MEADOW HEIGHTS
# 2  1.964803e+09  927571.0      E1 2019-04-03    3048.0  MEADOW HEIGHTS
# 3  1.964803e+09  927571.0      E1 2019-04-04    3048.0  MEADOW HEIGHTS
# 4  1.964803e+09  927571.0      E1 2019-04-05    3048.0  MEADOW HEIGHTS
#
#    ESTIMATE_READ_BITMASK_IND  MTR_REG_ACT_ENERGY_01_KWH  \
# 0                        0.0                     0.2562
# 1                        0.0                     0.3750
# 2                        0.0                     0.3750
# 3                        0.0                     0.1375
# 4                        0.0                     1.2062
#
#    MTR_REG_ACT_ENERGY_02_KWH  MTR_REG_ACT_ENERGY_03_KWH  ...  \
# 0                     0.2500                     0.2562  ...
# 1                     0.3500                     0.3312  ...
# ...
